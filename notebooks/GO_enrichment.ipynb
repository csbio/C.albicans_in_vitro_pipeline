# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
import os

# %%
from statsmodels.stats.multitest import fdrcorrection
from scipy.stats import hypergeom

# hypergeometric test:
# We can then compute a probability of drawing X red marbles out of N from 
# a jar containing n red marbles out of M in the following way:
def hyper_test(x, M, n, N):
    pval = hypergeom.sf(x-1, M, n, N)
    #print(pval)
    return pval

def get_BH_correct_pval(df, pval_col):
    (reject_list, pval_bh) = fdrcorrection(df[pval_col], alpha=0.05, method='indep', is_sorted=False)
    return pval_bh

# %%
# 07142023 - enrichment test on each condition-specific hit set
df_gobp_standard_5_200 = pd.read_csv('../data/input/go_bp_standard_Calb_5_200terms.txt', sep='\t', index_col=0)

# %%
df_gobp_standard_5_200
# Out:
#                                                    Name  \
# ID
# 1                  GO:0000001 mitochondrion inheritance
# 2           GO:0000002 mitochondrial genome maintenance
# 3                               GO:0000003 reproduction
# 4                        GO:0000011 vacuole inheritance
# 5            GO:0000018 regulation of DNA recombination
# ...                                                 ...
# 5462  GO:2001173 regulation of histone H2B conserved...
# 5465  GO:2001207 regulation of transcription elongat...
# 5467  GO:2001209 positive regulation of transcriptio...
# 5475  GO:2001251 negative regulation of chromosome o...
# 5476  GO:2001252 positive regulation of chromosome o...
#
#                                                   Genes  Length
# ID
# 1     orf19.6987;orf19.6071;orf19.4715;orf19.2987;or...      18
# 2     orf19.7538;orf19.5704;orf19.439;orf19.6672;orf...      31
# 3     orf19.7247;orf19.971;orf19.5292;orf19.796;orf1...     100
# 4     orf19.2245;orf19.7611;orf19.6364;orf19.1513;or...      20
# 5     orf19.4206;orf19.1755;orf19.2873;orf19.2983;or...      31
# ...                                                 ...     ...
# 5462  orf19.2983;orf19.7047;orf19.7067;orf19.7116;or...       5
# 5465  orf19.2983;orf19.7047;orf19.4123;orf19.7067;or...       8
# 5467  orf19.2983;orf19.7047;orf19.4123;orf19.7067;or...       8
# 5475  orf19.2402;orf19.3761;orf19.643;orf19.1185;orf...      33
# 5476  orf19.2402;orf19.3080;orf19.5416;orf19.5749;or...      16
#
# [2434 rows x 3 columns]

# %%
df_scores = pd.read_csv('../data/output/summary_mod_t_test_compare_median_normvar.csv', index_col=0)

# %%
df_scores.columns
# Out:
# Index(['plate', 'FBS_mean', 'FBS_fdr', 'Iron_mean', 'Iron_fdr', 'Temp37_mean',
#        'Temp37_fdr', 'YPD_mean', 'YPD_fdr', 'NaCl_mean', 'NaCl_fdr',
#        'SDS_mean', 'SDS_fdr', 'Sorbitol_mean', 'Sorbitol_fdr', 'YNB_mean',
#        'YNB_fdr'],
#       dtype='object')

# %%
# Write an enrichment function for each condition:
# population = 2k+ non-nan strains 
# success in population = # hits
# sample = # strains annotated to each GO term 
# success in sample: # hits in sample
def go_enrich_condition_hits(df_score, df_go_standard, 
                             condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc='./'):
    pan_essential_hits = df_score.index
    for cond in condition_list:
        print(cond)
        cond_mean = cond + '_mean'
        cond_fdr = cond + '_fdr'
        df_score_cond_mean = df_score[cond_mean]
        df_score_cond_fdr = df_score[cond_fdr]
        df_score_cond_mean_noNA = df_score_cond_mean[df_score_cond_mean.notnull()]
        df_score_cond_fdr_noNA = df_score_cond_fdr.loc[df_score_cond_mean_noNA.index]
        
        num_population = len(df_score_cond_mean_noNA)
        strains_mean_pass = df_score_cond_mean_noNA[df_score_cond_mean_noNA>=mean_cutoff].index
        strains_fdr_pass = df_score_cond_fdr_noNA[df_score_cond_fdr_noNA<=fdr_cutoff].index
        strains_hit = np.intersect1d(strains_mean_pass, strains_fdr_pass)
        num_hits = len(strains_hit)
        
        pan_essential_hits = np.intersect1d(pan_essential_hits, strains_hit)
        
        print(num_population, num_hits)
        
        df_go_standard_cond = enrich_go(df_go_standard, strains_total=df_score_cond_mean_noNA.index, 
                  strains_hit=strains_hit, output_direc=output_direc, condition=cond)
        print()
    
    num_pan_ess_hits = len(pan_essential_hits)
    print('#pan-essential:', num_pan_ess_hits)
    all_genes = df_score.index
    df_go_standard_pan = enrich_go(df_go_standard, strains_total=all_genes, 
                  strains_hit=pan_essential_hits, output_direc=output_direc, condition='pan_essential')
    return pan_essential_hits
    
    
def enrich_go(df_go_standard, strains_total, strains_hit, output_direc, condition):
    num_population = len(strains_total)
    num_hits = len(strains_hit)
    df_go_standard_cond = df_go_standard[['Name', 'Genes']]
    df_go_standard_cond.columns = ['GO_term', 'GO_term_genes']
    df_go_standard_cond['num_strains_total'] = np.nan
    df_go_standard_cond['num_strains_total_GOannotated'] = np.nan
    df_go_standard_cond['num_strain_hits'] = np.nan
    df_go_standard_cond['num_strains_hits_GOannotated'] = np.nan
    df_go_standard_cond['cond_enrich_pval'] = np.nan
    for row in df_go_standard.iterrows():
        go_idx = row[0]
        go_name = row[1]['Name']
        go_genes = row[1]['Genes'].split(';')
        go_in_pop = np.intersect1d(go_genes, strains_total)#df_score_cond_mean_noNA.index)
        go_in_hits = np.intersect1d(go_genes, strains_hit)
        len_go_in_pop = len(go_in_pop)
        len_go_in_hits = len(go_in_hits)
        if len_go_in_hits > 1:
            # We can then compute a probability of drawing X red marbles out of N from 
            # a jar containing n red marbles out of M in the following way:
            df_go_standard_cond.loc[go_idx, 'num_strains_total'] = num_population
            df_go_standard_cond.loc[go_idx, 'num_strains_total_GOannotated'] = len_go_in_pop
            df_go_standard_cond.loc[go_idx, 'num_strain_hits'] = num_hits
            df_go_standard_cond.loc[go_idx, 'num_strains_hits_GOannotated'] = len_go_in_hits

            go_pval = hyper_test(x=len_go_in_hits, M=num_population, n=num_hits, N=len_go_in_pop)
            df_go_standard_cond.loc[go_idx, 'cond_enrich_pval'] = go_pval
    df_go_standard_cond = df_go_standard_cond[df_go_standard_cond['cond_enrich_pval'].notnull()]
    df_go_standard_cond['cond_enrich_fdr'] = get_BH_correct_pval(df_go_standard_cond, pval_col='cond_enrich_pval')
    df_go_standard_cond = df_go_standard_cond.sort_values(by='cond_enrich_fdr', ascending=True)
    df_go_standard_cond['condition'] = condition
    if output_direc is not None:
        df_go_standard_cond.to_csv(output_direc+condition+'_go_enrich_results.tsv', sep='\t', index=None)
    return df_go_standard_cond

# %%
go_enrich_condition_hits(df_scores, df_gobp_standard_5_200, output_direc='../data/output/go_bp_enrich/')

# %%
go_bp_enrich_direc = '../data/output/go_bp_enrich/'

# %%
# 08132023 - GO enrichment on condition-specifc hits excluding pan-essential genes
# Note: Should drop YPD before this
# = Exclude 171 pan-essentials + 36 essenitials exclusive to YPD

# %%
df_scores_noYPD = df_scores.drop(['YPD_mean', 'YPD_fdr'], axis=1)

# %%
pan_essential_hits_noYPD = go_enrich_condition_hits(df_scores_noYPD, df_gobp_standard_5_200, 
                                                    condition_list=['FBS', 'Iron', 'Temp37', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                                    output_direc=None)
# Out:
# FBS
# 2219 308
#
# Iron
# 2223 242
#
# Temp37
# 2202 313
#
# NaCl
# 2187 296
#
# SDS
# 2227 273
#
# Sorbitol
# 2224 262
#
# YNB
# 2229 278
#
# #pan-essential: 207

# %%
len(pan_essential_hits_noYPD) # 171+36
# Out:
# 207

# %%
def go_enrich_condition_hits_no_pan(df_score, df_go_standard, pan_essential_hits,
                             condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc='./'):
    df_enrich_list = []
    for cond in condition_list:
        print(cond)
        cond_mean = cond + '_mean'
        cond_fdr = cond + '_fdr'
        df_score_cond_mean = df_score[cond_mean]
        df_score_cond_fdr = df_score[cond_fdr]
        df_score_cond_mean_noNA = df_score_cond_mean[df_score_cond_mean.notnull()]
        df_score_cond_fdr_noNA = df_score_cond_fdr.loc[df_score_cond_mean_noNA.index]
        
        
        strains_mean_pass = df_score_cond_mean_noNA[df_score_cond_mean_noNA>=mean_cutoff].index
        strains_fdr_pass = df_score_cond_fdr_noNA[df_score_cond_fdr_noNA<=fdr_cutoff].index
        strains_hit = np.intersect1d(strains_mean_pass, strains_fdr_pass)
        num_hits = len(strains_hit)
        
        strains_hit_no_pan = list(set(strains_hit) - set(pan_essential_hits))
        
        #pan_essential_hits = np.intersect1d(pan_essential_hits, strains_hit)
        
        bg_genes = list(set(df_score_cond_mean_noNA.index) - set(pan_essential_hits))
        num_population = len(bg_genes)
        print(num_population, num_hits, len(strains_hit_no_pan))
        
        df_go_standard_cond = enrich_go(df_go_standard, strains_total=bg_genes, 
                  strains_hit=strains_hit_no_pan, output_direc=output_direc, condition=cond)
        df_enrich_list.append(df_go_standard_cond)
        print()
    df_enrich = pd.concat(df_enrich_list)
    return df_enrich

# %%
df_enrich_no_pan_noYPD = go_enrich_condition_hits_no_pan(df_scores_noYPD, df_gobp_standard_5_200, 
                                                   pan_essential_hits=pan_essential_hits_noYPD,
                                                   condition_list=['FBS', 'Iron', 'Temp37', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                output_direc=go_bp_enrich_direc+'go_bp_enrich_exclude_pan&YPD/')
# Out:
# FBS
# 2012 308 101
#
# Iron
# 2016 242 35
#
# Temp37
# 1995 313 106
#
# NaCl
# 1980 296 89
#
# SDS
# 2020 273 66
#
# Sorbitol
# 2017 262 55
#
# YNB
# 2022 278 71

# %%
df_enrich_no_pan_noYPD
# Out:
#                                                 GO_term  \
# ID
# 156   GO:0000727 double-strand break repair via brea...
# 575   GO:0006490 oligosaccharide-lipid intermediate ...
# 476                        GO:0006310 DNA recombination
# 1936                   GO:0031123 RNA 3'-end processing
# 3548                  GO:0051640 organelle localization
# ...                                                 ...
# 3059           GO:0045927 positive regulation of growth
# 4248  GO:0090033 positive regulation of filamentous ...
# 4634  GO:1900430 positive regulation of filamentous ...
# 934                GO:0008202 steroid metabolic process
# 3347        GO:0050790 regulation of catalytic activity
#
#                                           GO_term_genes  num_strains_total  \
# ID
# 156   orf19.4206;orf19.4545;orf19.1988;orf19.2740;or...             2012.0
# 575   orf19.4410;orf19.7391;orf19.1092;orf19.1203.1;...             2012.0
# 476   orf19.4206;orf19.5873;orf19.967;orf19.5844;orf...             2012.0
# 1936  orf19.2402;orf19.4538;orf19.684;orf19.3333;orf...             2012.0
# 3548  orf19.6479;orf19.3465;orf19.3248;orf19.6346;or...             2012.0
# ...                                                 ...                ...
# 3059  orf19.7247;orf19.971;orf19.5672;orf19.3256;orf...             2022.0
# 4248  orf19.7247;orf19.971;orf19.5672;orf19.3256;orf...             2022.0
# 4634  orf19.7247;orf19.971;orf19.5672;orf19.3256;orf...             2022.0
# 934   orf19.5535;orf19.3240;orf19.3642;orf19.1478;or...             2022.0
# 3347  orf19.4206;orf19.7250;orf19.5671;orf19.4616;or...             2022.0
#
#       num_strains_total_GOannotated  num_strain_hits  \
# ID
# 156                            13.0            101.0
# 575                             4.0            101.0
# 476                            48.0            101.0
# 1936                           14.0            101.0
# 3548                           46.0            101.0
# ...                             ...              ...
# 3059                           64.0             71.0
# 4248                           64.0             71.0
# 4634                           64.0             71.0
# 934                            65.0             71.0
# 3347                           71.0             71.0
#
#       num_strains_hits_GOannotated  cond_enrich_pval  cond_enrich_fdr  \
# ID
# 156                            5.0          0.000270         0.029198
# 575                            3.0          0.000474         0.029198
# 476                            9.0          0.000462         0.029198
# 1936                           5.0          0.000403         0.029198
# 3548                           9.0          0.000330         0.029198
# ...                            ...               ...              ...
# 3059                           2.0          0.666793         0.670062
# 4248                           2.0          0.666793         0.670062
# 4634                           2.0          0.666793         0.670062
# 934                            2.0          0.675209         0.676860
# 3347                           2.0          0.722188         0.722188
#
#      condition
# ID
# 156        FBS
# 575        FBS
# 476        FBS
# 1936       FBS
# 3548       FBS
# ...        ...
# 3059       YNB
# 4248       YNB
# 4634       YNB
# 934        YNB
# 3347       YNB
#
# [2683 rows x 9 columns]

# %%
df_enrich_no_pan_noYPD.to_csv(go_bp_enrich_direc+'go_bp_enrich_exclude_pan&YPD/all_conditions_go_enrich_results.tsv', sep='\t', index=None)

# %%
# 08152023 - Do enrichment analysis on the subgroup of genes considering all tested mutants as background
# Build a function that consider genes exclusively essential in the provided conditions
def go_enrich_condition_hits_exclusive(df_score_all, df_go_standard, 
                             all_condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                       subset_condition_list=['YPD'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc='./'):
    # First, get the subset of all other conditions and exclude any hits
    all_condition_list_mean = [s + '_mean' for s in all_condition_list]
    all_condition_list_fdr = [s + '_fdr' for s in all_condition_list]
    sub_condition_list_mean = [s + '_mean' for s in subset_condition_list]
    sub_condition_list_fdr = [s + '_fdr' for s in subset_condition_list]
    
    df_score = df_score_all[all_condition_list_mean + all_condition_list_fdr] # This helps cases where we don't need YPD (no need to include in all)
    any_other_hits = []
    other_conditions_mean_fdr = list(set(all_condition_list_mean + all_condition_list_fdr) - set(sub_condition_list_mean+sub_condition_list_fdr))
    df_others = df_score[other_conditions_mean_fdr]
    other_conditions = list(set(all_condition_list)-set(subset_condition_list))
    for cond in other_conditions:
        cond_mean = cond + '_mean'
        cond_fdr = cond + '_fdr'
        df_score_cond_mean = df_others[cond_mean]
        df_score_cond_fdr = df_others[cond_fdr]
        df_score_cond_mean_noNA = df_score_cond_mean[df_score_cond_mean.notnull()]
        df_score_cond_fdr_noNA = df_score_cond_fdr.loc[df_score_cond_mean_noNA.index]
        strains_mean_pass = df_score_cond_mean_noNA[df_score_cond_mean_noNA>=mean_cutoff].index
        strains_fdr_pass = df_score_cond_fdr_noNA[df_score_cond_fdr_noNA<=fdr_cutoff].index
        strains_hit = np.intersect1d(strains_mean_pass, strains_fdr_pass)
        any_other_hits = np.union1d(any_other_hits, strains_hit)
    
    print("All other hits to exclude:", len(any_other_hits))
    
    # Second, from the subset, get the essential hits for the given condition(s)
    # Q: do we exclude other hits from the background? - probably no need to
    df_enrich_list = []
    df_score_no_other_hits = df_score.drop(any_other_hits)
    pan_essential_hits = df_score.index
    bg_gene_list = []
    for cond in subset_condition_list:
        print(cond)
        cond_mean = cond + '_mean'
        cond_fdr = cond + '_fdr'
        df_score_cond_mean = df_score_no_other_hits[cond_mean]
        df_score_cond_fdr = df_score_no_other_hits[cond_fdr]
        df_score_cond_mean_noNA = df_score_cond_mean[df_score_cond_mean.notnull()]
        df_score_cond_fdr_noNA = df_score_cond_fdr.loc[df_score_cond_mean_noNA.index]
        
        bg_genes = np.union1d(any_other_hits, df_score_cond_mean_noNA.index)
        num_population = len(bg_genes)
        bg_gene_list.extend(bg_genes.tolist())
        
        strains_mean_pass = df_score_cond_mean_noNA[df_score_cond_mean_noNA>=mean_cutoff].index
        strains_fdr_pass = df_score_cond_fdr_noNA[df_score_cond_fdr_noNA<=fdr_cutoff].index
        strains_hit = np.intersect1d(strains_mean_pass, strains_fdr_pass)
        num_hits = len(strains_hit)

        print(num_population, num_hits)
        
        pan_essential_hits = np.intersect1d(pan_essential_hits, strains_hit)
        
        #df_go_standard_cond = enrich_go(df_go_standard, strains_total=bg_genes, 
        #          strains_hit=strains_hit, output_direc=output_direc, condition=cond)
        #df_enrich_list.append(df_go_standard_cond)
        print()
    bg_gene_list = np.unique(bg_gene_list)
    num_pan_ess_hits = len(pan_essential_hits)
    print('#pan-essential:', num_pan_ess_hits)
    all_genes = df_score.index
    df_go_standard_pan = enrich_go(df_go_standard, strains_total=bg_gene_list, 
                  strains_hit=pan_essential_hits, output_direc=output_direc, condition=';'.join(subset_condition_list))
    #df_enrich = pd.concat(df_enrich_list)
    return df_go_standard_pan

# %%
# 1. 39 genes only essential to YPD but not to others
df_enrich_YPDonly = go_enrich_condition_hits_exclusive(df_scores, df_gobp_standard_5_200,
                             all_condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                       subset_condition_list=['YPD'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc=None)
# Out:
# All other hits to exclude: 389
# YPD
# 2228 39
#
# #pan-essential: 39

# %%
df_enrich_YPDonly.to_csv(go_bp_enrich_direc+'go_bp_enrich_subsets/YPD_only_39genes_go_enrich_results.tsv', sep='\t', index=None)

# %%
df_enrich_YPDonly
# Out:
#                                                 GO_term  \
# ID
# 1126                      GO:0009303 rRNA transcription
# 2684  GO:0042790 nucleolar large rRNA transcription ...
# 4430                     GO:0098781 ncRNA transcription
# 1947  GO:0031145 anaphase-promoting complex-dependen...
# 3987                   GO:0071043 CUT metabolic process
# ...                                                 ...
# 3041  GO:0045892 negative regulation of DNA-template...
# 5042  GO:1903507 negative regulation of nucleic acid...
# 4547                        GO:0140352 export from cell
# 3453  GO:0051253 negative regulation of RNA metaboli...
# 1552                         GO:0016310 phosphorylation
#
#                                           GO_term_genes  num_strains_total  \
# ID
# 1126  orf19.2873;orf19.274;orf19.6921;orf19.519;orf1...             2228.0
# 2684  orf19.6921;orf19.519;orf19.4896;orf19.1589;orf...             2228.0
# 4430  orf19.4537;orf19.7538;orf19.2847;orf19.2831;or...             2228.0
# 1947  orf19.5954;orf19.3471;orf19.5056;orf19.2084;or...             2228.0
# 3987  orf19.4582;orf19.1304;orf19.58;orf19.5229;orf1...             2228.0
# ...                                                 ...                ...
# 3041  orf19.7247;orf19.1755;orf19.1343;orf19.1059;or...             2228.0
# 5042  orf19.7247;orf19.1755;orf19.1343;orf19.1059;or...             2228.0
# 4547  orf19.5604;orf19.2078;orf19.136;orf19.6479;orf...             2228.0
# 3453  orf19.7247;orf19.1755;orf19.1343;orf19.1059;or...             2228.0
# 1552  orf19.6745;orf19.4443;orf19.5257;orf19.5297;or...             2228.0
#
#       num_strains_total_GOannotated  num_strain_hits  \
# ID
# 1126                            6.0             39.0
# 2684                            2.0             39.0
# 4430                           12.0             39.0
# 1947                            5.0             39.0
# 3987                            7.0             39.0
# ...                             ...              ...
# 3041                           88.0             39.0
# 5042                           88.0             39.0
# 4547                           91.0             39.0
# 3453                           91.0             39.0
# 1552                          103.0             39.0
#
#       num_strains_hits_GOannotated  cond_enrich_pval  cond_enrich_fdr  \
# ID
# 1126                           3.0          0.000096         0.011774
# 2684                           2.0          0.000299         0.018369
# 4430                           3.0          0.000979         0.040130
# 1947                           2.0          0.002889         0.048075
# 3987                           2.0          0.005933         0.048075
# ...                            ...               ...              ...
# 3041                           2.0          0.460687         0.472204
# 5042                           2.0          0.460687         0.472204
# 4547                           2.0          0.478394         0.482316
# 3453                           2.0          0.478394         0.482316
# 1552                           2.0          0.545731         0.545731
#
#      condition
# ID
# 1126       YPD
# 2684       YPD
# 4430       YPD
# 1947       YPD
# 3987       YPD
# ...        ...
# 3041       YPD
# 5042       YPD
# 4547       YPD
# 3453       YPD
# 1552       YPD
#
# [123 rows x 9 columns]

# %%
# 2. 18 genes only essential to YNB37 but not to others
df_enrich_Temp37only = go_enrich_condition_hits_exclusive(df_scores, df_gobp_standard_5_200,
                             all_condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                       subset_condition_list=['Temp37'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc=None)
# Out:
# All other hits to exclude: 410
# Temp37
# 2218 18
#
# #pan-essential: 18

# %%
df_enrich_Temp37only.to_csv(go_bp_enrich_direc+'go_bp_enrich_subsets/Temp37_only_18genes_go_enrich_results.tsv', sep='\t', index=None)

# %%
df_enrich_Temp37only
# Out:
#                                                 GO_term  \
# ID
# 1999      GO:0031505 fungal-type cell wall organization
# 4222     GO:0075259 spore-bearing structure development
# 4086                  GO:0071555 cell wall organization
# 2977  GO:0045229 external encapsulating structure or...
# 3324      GO:0048608 reproductive structure development
# 483                     GO:0006338 chromatin remodeling
# 3569  GO:0051701 biological process involved in inte...
# 2909  GO:0044403 biological process involved in symb...
# 4648  GO:1900445 positive regulation of filamentous ...
# 285   GO:0002833 positive regulation of response to ...
# 3328        GO:0048856 anatomical structure development
# 4426                        GO:0098743 cell aggregation
# 4409    GO:0098630 aggregation of unicellular organisms
# 4346  GO:0090609 single-species submerged biofilm fo...
# 4344             GO:0090605 submerged biofilm formation
# 3570  GO:0051703 biological process involved in intr...
# 283   GO:0002831 regulation of response to biotic st...
# 2858  GO:0044011 single-species biofilm formation on...
# 2857        GO:0044010 single-species biofilm formation
0
#
#       num_strains_total_GOannotated  num_strain_hits  \
# ID
# 1999                           90.0             18.0
# 4222                           14.0             18.0
# 4086                           91.0             18.0
# 2977                           91.0             18.0
# 3324                           14.0             18.0
# 483                            75.0             18.0
# 3569                           72.0             18.0
# 2909                           72.0             18.0
# 4648                           39.0             18.0
# 285                            39.0             18.0
# 3328                           39.0             18.0
# 4426                           60.0             18.0
# 4409                           60.0             18.0
# 4346                           53.0             18.0
# 4344                           53.0             18.0
# 3570                           60.0             18.0
# 283                            44.0             18.0
# 2858                           53.0             18.0
# 2857                           56.0             18.0
# 293                            59.0             18.0
# 2662                           60.0             18.0
# 4646                           44.0             18.0
# 1542                           55.0             18.0
# 4248                           68.0             18.0
# 3059                           68.0             18.0
# 4634                           68.0             18.0
# 2392                           65.0             18.0
# 830                            71.0             18.0
# 3321                           81.0             18.0
# 4007                           88.0             18.0
# 4456                           88.0             18.0
# 3174                           89.0             18.0
# 3813                           91.0             18.0
# 1515                           97.0             18.0
#
#       num_strains_hits_GOannotated  cond_enrich_pval  cond_enrich_fdr  \
# ID
# 1999                           4.0          0.005012         0.036344
# 4222                           2.0          0.005345         0.036344
# 4086                           4.0          0.005216         0.036344
# 2977                           4.0          0.005216         0.036344
# 3324                           2.0          0.005345         0.036344
# 483                            3.0          0.021027         0.089364
# 3569                           3.0          0.018857         0.089364
# 2909                           3.0          0.018857         0.089364
# 4648                           2.0          0.038608         0.119333
# 285                            2.0          0.038608         0.119333
# 3328                           2.0          0.038608         0.119333
# 4426                           2.0          0.083453         0.123365
# 4409                           2.0          0.083453         0.123365
# 4346                           2.0          0.067165         0.123365
# 4344                           2.0          0.067165         0.123365
# 3570                           2.0          0.083453         0.123365
# 283                            2.0          0.048127         0.123365
# 2858                           2.0          0.067165         0.123365
# 2857                           2.0          0.074000         0.123365
# 293                            2.0          0.081054         0.123365
# 2662                           2.0          0.083453         0.123365
# 4646                           2.0          0.048127         0.123365
# 1542                           2.0          0.071696         0.123365
# 4248                           2.0          0.103413         0.130224
# 3059                           2.0          0.103413         0.130224
# 4634                           2.0          0.103413         0.130224
# 2392                           2.0          0.095774         0.130224
# 830                            2.0          0.111223         0.135056
# 3321                           2.0          0.138339         0.162190
# 4007                           2.0          0.158158         0.171101
# 4456                           2.0          0.158158         0.171101
# 3174                           2.0          0.161037         0.171101
# 3813                           2.0          0.166826         0.171882
# 1515                           2.0          0.184429         0.184429
#
#      condition
# ID
# 1999    Temp37
# 4222    Temp37
# 4086    Temp37
# 2977    Temp37
# 3324    Temp37
# 483     Temp37
# 3569    Temp37
# 2909    Temp37
# 4648    Temp37
# 285     Temp37
# 3328    Temp37
# 4426    Temp37
# 4409    Temp37
# 4346    Temp37
# 4344    Temp37
# 3570    Temp37
# 283     Temp37
# 2858    Temp37
# 2857    Temp37
# 293     Temp37
# 2662    Temp37
# 4646    Temp37
# 1542    Temp37
# 4248    Temp37
# 3059    Temp37
# 4634    Temp37
# 2392    Temp37
# 830     Temp37
# 3321    Temp37
# 4007    Temp37
# 4456    Temp37
# 3174    Temp37
# 3813    Temp37
# 1515    Temp37

# %%
# 3. 12 genes only essential to YPD & SERUM (FBS) but not to others
df_enrich_YPD_FBS_only = go_enrich_condition_hits_exclusive(df_scores, df_gobp_standard_5_200,
                             all_condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                       subset_condition_list=
# 4256   YPD;FBS
# 1518   YPD;FBS
# 2630   YPD;FBS
# 2872   YPD;FBS
# 3417   YPD;FBS
# 1491   YPD;FBS
# 2392   YPD;FBS
# 1987   YPD;FBS
# 1656   YPD;FBS
# 915    YPD;FBS
# 3423   YPD;FBS
# 3548   YPD;FBS
# 2866   YPD;FBS
# 3418   YPD;FBS
# 830    YPD;FBS
# 820    YPD;FBS
# 3813   YPD;FBS

# %%
# 4. 11 genes only essential to YPD & SERUM (FBS) & NaCl but not to others
df_enrich_YPD_FBS_NaCl_only = go_enrich_condition_hits_exclusive(df_scores, df_gobp_standard_5_200,
                             all_condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                       subset_condition_list=['YPD', 'FBS', 'NaCl'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc=None)
# Out:
# All other hits to exclude: 342
# YPD
# 2226 66
#
# FBS
# 2229 33
#
# NaCl
# 2206 28
#
# #pan-essential: 11

# %%
df_enrich_YPD_FBS_NaCl_only.to_csv(go_bp_enrich_direc+'go_bp_enrich_subsets/YPD_FBS_NaCl_only_11genes_go_enrich_results.tsv', sep='\t', index=None)

# %%
df_enrich_YPD_FBS_NaCl_only
# Out:
#                                                 GO_term  \
# ID
# 3890  GO:0070525 tRNA threonylcarbamoyladenosine met...
# 500   GO:0006369 termination of RNA polymerase II tr...
# 152   GO:0000722 telomere maintenance via recombination
# 486   GO:0006353 DNA-templated transcription termina...
# 478                    GO:0006312 mitotic recombination
# 1518                  GO:0016071 mRNA metabolic process
# 153                     GO:0000723 telomere maintenance
# 514                          GO:0006397 mRNA processing
# 2084                   GO:0032200 telomere organization
# 925                          GO:0008033 tRNA processing
# 1797      GO:0022618 ribonucleoprotein complex assembly
# 515                   GO:0006399 tRNA metabolic process
# 476                        GO:0006310 DNA recombination
# 2619      GO:0042273 ribosomal large subunit biogenesis
# 560                  GO:0006468 protein phosphorylation
# 3041  GO:0045892 negative regulation of DNA-template...
# 3453  GO:0051253 negative regulation of RNA metaboli...
# 4896  GO:1902679 negative regulation of RNA biosynth...
# 5042  GO:1903507 negative regulation of nucleic acid...
# 1552                         GO:0016310 phosphorylation
#
#                                           GO_term_genes  num_strains_total  \
# ID
# 3890  orf19.4160;orf19.1305;orf19.3787;orf19.7081;or...             2232.0
# 500   orf19.2402;orf19.684;orf19.6010.1;orf19.6230;o...             2232.0
# 152   orf19.2267;orf19.3787;orf19.3752;orf19.4208;or...             2232.0
# 486   orf19.1755;orf19.2402;orf19.684;orf19.6010.1;o...             2232.0
# 478   orf19.5873;orf19.2267;orf19.5318;orf19.3787;or...             2232.0
# 1518  orf19.4010;orf19.4045;orf19.1261;orf19.2402;or...             2232.0
# 153   orf19.7538;orf19.4045;orf19.1972;orf19.926;orf...             2232.0
# 514   orf19.1261;orf19.2402;orf19.4538;orf19.684;orf...             2232.0
# 2084  orf19.7538;orf19.4045;orf19.5053;orf19.1972;or...             2232.0
# 925   orf19.4160;orf19.1305;orf19.1261;orf19.4168;or...             2232.0
# 1797  orf19.7624;orf19.4746;orf19.135;orf19.7545;orf...             2232.0
# 515   orf19.4160;orf19.4537;orf19.1305;orf19.1261;or...             2232.0
# 476   orf19.4206;orf19.5873;orf19.967;orf19.5844;orf...             2232.0
# 2619  orf19.4443;orf19.4746;orf19.6347;orf19.6400;or...             2232.0
# 560   orf19.5297;orf19.5350;orf19.3256;orf19.829;orf...             2232.0
# 3041  orf19.7247;orf19.1755;orf19.1343;orf19.1059;or...             2232.0
# 3453  orf19.7247;orf19.1755;orf19.1343;orf19.1059;or...             2232.0
# 4896  orf19.7247;orf19.1755;orf19.1343;orf19.1059;or...             2232.0
# 5042  orf19.7247;orf19.1755;orf19.1343;orf19.1059;or...             2232.0
# 1552  orf19.6745;orf19.4443;orf19.5257;orf19.5297;or...             2232.0
#
#       num_strains_total_GOannotated  num_strain_hits  \
# ID
# 3890                            6.0             11.0
# 500                            10.0             11.0
# 152                            14.0             11.0
# 486                            14.0             11.0
# 478                            18.0             11.0
# 1518                           67.0             11.0
# 153                            32.0             11.0
# 514                            34.0             11.0
# 2084                           33.0             11.0
# 925                            39.0             11.0
# 1797                           55.0             11.0
# 515                            51.0             11.0
# 476                            55.0             11.0
# 2619                           64.0             11.0
# 560                            91.0             11.0
# 3041                           88.0             11.0
# 3453                           91.0             11.0
# 4896                           88.0             11.0
# 5042                           88.0             11.0
# 1552                          103.0             11.0
#
#       num_strains_hits_GOannotated  cond_enrich_pval  cond_enrich_fdr  \
# ID
# 3890                           2.0          0.000328         0.006556
# 500                            2.0          0.000973         0.009729
# 152                            2.0          0.001946         0.009731
# 486                            2.0          0.001946         0.009731
# 478                            2.0          0.003237         0.011969
# 1518                           3.0          0.003591         0.011969
# 153                            2.0          0.010106         0.025264
# 514                            2.0          0.011369         0.025264
# 2084                           2.0          0.010729         0.025264
# 925                            2.0          0.014816         0.029632
# 1797                           2.0          0.028440         0.043754
# 515                            2.0          0.024682         0.043754
# 476                            2.0          0.028440         0.043754
# 2619                           2.0          0.037685         0.053836
# 560                            2.0          0.071185         0.074932
# 3041                           2.0          0.067083         0.074932
# 3453                           2.0          0.071185         0.074932
# 4896                           2.0          0.067083         0.074932
# 5042                           2.0          0.067083         0.074932
# 1552                           2.0          0.088417         0.088417
#
#          condition
# ID
# 3890  YPD;FBS;NaCl
# 500   YPD;FBS;NaCl
# 152   YPD;FBS;NaCl
# 486   YPD;FBS;NaCl
# 478   YPD;FBS;NaCl
# 1518  YPD;FBS;NaCl
# 153   YPD;FBS;NaCl
# 514   YPD;FBS;NaCl
# 2084  YPD;FBS;NaCl
# 925   YPD;FBS;NaCl
# 1797  YPD;FBS;NaCl
# 515   YPD;FBS;NaCl
# 476   YPD;FBS;NaCl
# 2619  YPD;FBS;NaCl
# 560   YPD;FBS;NaCl
# 3041  YPD;FBS;NaCl
# 3453  YPD;FBS;NaCl
# 4896  YPD;FBS;NaCl
# 5042  YPD;FBS;NaCl
# 1552  YPD;FBS;NaCl

# %%
# 5. 10 genes only essential to NaCl but not to others
df_enrich_NaCl_only = go_enrich_condition_hits_exclusive(df_scores, df_gobp_standard_5_200,
                             all_condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                       subset_condition_list=['NaCl'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc=None)
# Out:
# All other hits to exclude: 418
# NaCl
# 2210 10
#
# #pan-essential: 10

# %%
df_enrich_NaCl_only.to_csv(go_bp_enrich_direc+'go_bp_enrich_subsets/NaCl_only_10genes_go_enrich_results.tsv', sep='\t', index=None)

# %%
df_enrich_NaCl_only
# Out:
#                                                 GO_term  \
# ID
# 403   GO:0006164 purine nucleotide biosynthetic process
# 1111     GO:0009260 ribonucleotide biosynthetic process
# 1044  GO:0009152 purine ribonucleotide biosynthetic ...
# 3172   GO:0046390 ribose phosphate biosynthetic process
# 1054         GO:0009165 nucleotide biosynthetic process
# 1110        GO:0009259 ribonucleotide metabolic process
# 4187  GO:0072522 purine-containing compound biosynth...
# 1042  GO:0009150 purine ribonucleotide metabolic pro...
# 4703  GO:1901293 nucleoside phosphate biosynthetic p...
# 402      GO:0006163 purine nucleotide metabolic process
# 4012                           2.0          0.010697         0.011003
# 1215                           2.0          0.020107         0.020107
#
#      condition
# ID
# 403       NaCl
# 1111      NaCl
# 1044      NaCl
# 3172      NaCl
# 1054      NaCl
# 1110      NaCl
# 4187      NaCl
# 1042      NaCl
# 4703      NaCl
# 402       NaCl
# 414       NaCl
# 1755      NaCl
# 3102      NaCl
# 413       NaCl
# 4186      NaCl
# 3088      NaCl
# 3101      NaCl
# 1056      NaCl
# 1057      NaCl
# 1022      NaCl
# 1021      NaCl
# 1047      NaCl
# 1013      NaCl
# 1019      NaCl
# 1050      NaCl
# 1015      NaCl
# 1018      NaCl
# 396       NaCl
# 731       NaCl
# 3113      NaCl
# 3656      NaCl
# 1012      NaCl
# 4015      NaCl
# 1217      NaCl
# 4012      NaCl
# 1215      NaCl

# %%
# 6. 9 genes only essential to all conditions except for FeFree (Iron)
df_enrich_all_but_iron = go_enrich_condition_hits_exclusive(df_scores, df_gobp_standard_5_200,
                             all_condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                       subset_condition_list=['FBS', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc=None)
# Out:
# All other hits to exclude: 242
# FBS
# 2222 82
#
# Temp37
# 2204 79
#
# YPD
# 2217 110
#
# NaCl
# 2192 75
#
# SDS
# 2227 41
#
# Sorbitol
# 2227 41
#
# YNB
# 2230 44
#
# #pan-essential: 9

# %%
df_enrich_all_but_iron.to_csv(go_bp_enrich_direc+'go_bp_enrich_subsets/all_but_iron_9genes_go_enrich_results.tsv', sep='\t', index=None)

# %%
df_enrich_all_but_iron
# Out:
#                                                 GO_term  \
# ID
# 440            GO:0006261 DNA-templated DNA replication
# 439                          GO:0006260 DNA replication
# 3926  GO:0070786 positive regulation of growth of un...
# 470               GO:0006302 double-strand break repair
# 3561  GO:0051656 establishment of organelle localiza...
# 3924  GO:0070784 regulation of growth of unicellular...
# 3417                          GO:0051168 nuclear export
# 820              GO:0006913 nucleocytoplasmic transport
# 3059           GO:0045927 positive regulation of growth
# 3418                       GO:0051169 nuclear transport
# 3548                  GO:0051640 organelle localization
# 4248  GO:0090033 positive regulation of filamentous ...
# 4634  GO:1900430 positive regulation of filamentous ...
# 3321  GO:0048584 positive regulation of response to ...
# 4007   GO:0071214 cellular response to abiotic stimulus
# 4456  GO:0104004 cellular response to environmental ...
#
#                                           GO_term_genes  num_strains_total  \
# ID
# 440   orf19.5873;orf19.5166;orf19.2740;orf19.3373;or...             2236.0
# 439   orf19.5873;orf19.7538;orf19.5053;orf19.5166;or...             2236.0
# 3926  orf19.5908;orf19.1526;orf19.6010;orf19.5251;or...             2236.0
# 470   orf19.4206;orf19.5873;orf19.5053;orf19.4545;or...             2236.0
# 3561  orf19.3465;orf19.3248;orf19.6346;orf19.6987;or...             2236.0
# 3924  orf19.1666;orf19.2646;orf19.4044;orf19.5908;or...             2236.0
# 3417  orf19.3465;orf19.6346;orf19.3865;orf19.200;orf...             2236.0
# 820   orf19.5994;orf19.3465;orf19.6346;orf19.6400;or...             2236.0
# 3059  orf19.7247;orf19.971;orf19.5672;orf19.3256;orf...             2236.0
# 3418  orf19.5994;orf19.3465;orf19.6346;orf19.6400;or...             2236.0
# 3548  orf19.6479;orf19.3465;orf19.3248;orf19.6346;or...             2236.0
# 4248  orf19.7247;orf19.971;orf19.5672;orf19.3256;orf...             2236.0
# 4634  orf19.7247;orf19.971;orf19.5672;orf19.3256;orf...             2236.0
# 3321  orf19.6745;orf19.3617;orf19.7247;orf19.971;orf...             2236.0
# 4007  orf19.4443;orf19.7247;orf19.897;orf19.971;orf1...             2236.0
# 4456  orf19.4443;orf19.7247;orf19.897;orf19.971;orf1...             2236.0
#
#       num_strains_total_GOannotated  num_strain_hits  \
# ID
# 440                            11.0              9.0
# 439                            18.0              9.0
# 3926                           19.0              9.0
# 470                            38.0              9.0
# 3561                           34.0              9.0
# 3924                           41.0              9.0
# 3417                           48.0              9.0
# 820                            71.0              9.0
# 3059                           68.0              9.0
# 3418                           71.0              9.0
# 3548                           62.0              9.0
# 4248                           68.0              9.0
# 4634                           68.0              9.0
# 3321                           81.0              9.0
# 4007                           89.0              9.0
# 4456                           89.0              9.0
#
#       num_strains_hits_GOannotated  cond_enrich_pval  cond_enrich_fdr  \
# ID
# 440                            2.0          0.000778         0.012442
# 439                            2.0          0.002132         0.012680
# 3926                           2.0          0.002378         0.012680
# 470                            2.0          0.009393         0.029034
# 3561                           2.0          0.007559         0.029034
# 3924                           2.0          0.010888         0.029034
# 3417                           2.0          0.014759         0.033734
# 820                            2.0          0.030982         0.038131
# 3059                           2.0          0.028580         0.038131
# 3418                           2.0          0.030982         0.038131
# 3548                           2.0          0.024026         0.038131
# 4248                           2.0          0.028580         0.038131
# 4634                           2.0          0.028580         0.038131
# 3321                           2.0          0.039555         0.045205
# 4007                           2.0          0.047010         0.047010
# 4456                           2.0          0.047010         0.047010
#
#                                  condition
# ID
# 440   FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 439   FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 3926  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 470   FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 3561  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 3924  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 3417  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 820   FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 3059  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 3418  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 3548  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 4248  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 4634  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 3321  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 4007  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB
# 4456  FBS;Temp37;YPD;NaCl;SDS;Sorbitol;YNB

# %%
# 7. 7 genes only essential to SERUM (FBS) but not to others
df_enrich_FBS_only = go_enrich_condition_hits_exclusive(df_scores, df_gobp_standard_5_200,
                             all_condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                       subset_condition_list=['FBS'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc=None)
# Out:
# All other hits to exclude: 421
# FBS
# 2229 7
#
# #pan-essential: 7

# %%
df_enrich_FBS_only
# Out:
# Empty DataFrame
# Columns: [GO_term, GO_term_genes, num_strains_total, num_strains_total_GOannotated, num_strain_hits, num_strains_hits_GOannotated, cond_enrich_pval, cond_enrich_fdr, condition]
# Index: []

# %%
# 10042023: 
# 36 genes essential to all but YPD
df_enrich_allButYPD = go_enrich_condition_hits_exclusive(df_scores, df_gobp_standard_5_200,
                             all_condition_list=['FBS', 'Iron', 'Temp37', 'YPD', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                                       subset_condition_list=['FBS', 'Iron', 'Temp37', 'NaCl', 'SDS', 'Sorbitol', 'YNB'],
                            mean_cutoff=2, fdr_cutoff=0.05, output_direc=None)
# Out:
# All other hits to exclude: 300
# FBS
# 2222 64
#
# Iron
# 2225 52
#
# Temp37
# 2207 91
#
# NaCl
# 2193 73
#
# SDS
# 2227 65
#
# Sorbitol
# 2225 61
#
# YNB
# 2231 70
#
# #pan-essential: 36

# %%
df_enrich_allButYPD.to_csv(go_bp_enrich_direc+'go_bp_enrich_results/go_bp_enrich_subsets/all_but_YPD_36genes_go_enrich_results.tsv', sep='\t', index=None)
