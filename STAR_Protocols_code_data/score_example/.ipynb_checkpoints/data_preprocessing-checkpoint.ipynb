# %%
# 09202024: clean and merge the two protocol data files
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv('protocol_1.csv', index_col=0)
df_2 = pd.read_csv('protocol_2.csv', index_col=0)

# %%
df_1
# Out:
#                 feature common  \
# orf19
# orf19.10    CR_07130C_A    NaN
# orf19.100   C6_00980C_A    NaN
# orf19.1002  C1_10560C_A    NaN
# orf19.1005  C1_10570C_A    NaN
# orf19.101   C6_00990W_A   RIM9
# ...                 ...    ...
# orf19.979   C5_00190C_A   FAS1
# orf19.984   C1_10430W_A    NaN
# orf19.988   C1_10460W_A   GPC1
# orf19.99    C6_00970C_A  MET22
# orf19.991   C1_10480W_A   DJP1
#
#                                                   description         plate  \
# orf19
# orf19.10    Alkane-inducible cytochrome P450; catalyzes hy...      Plate 21
# orf19.100   Alpha/beta hydrolase and lipase domain protein...  GELCPlate 08
# orf19.1002  Protein of unknown function; Hap43-repressed gene  GELCPlate 08
# orf19.1005  Protein with predicted RNI-like domains; rat c...  GELCPlate 05
# orf19.101   Protein required for alkaline pH response via ...  GELCPlate 08
# ...                                                       ...           ...
# ...

# %%
df_2
# Out:
#                 feature common  \
# orf19
# orf19.10    CR_07130C_A    NaN
# orf19.100   C6_00980C_A    NaN
# orf19.1002  C1_10560C_A    NaN
# orf19.1005  C1_10570C_A    NaN
# orf19.101   C6_00990W_A   RIM9
# ...                 ...    ...
# orf19.979   C5_00190C_A   FAS1
# orf19.984   C1_10430W_A    NaN
# orf19.988   C1_10460W_A   GPC1
# orf19.99    C6_00970C_A  MET22
# orf19.991   C1_10480W_A   DJP1
#
#                                                   description         plate  \
# orf19
# orf19.10    Alkane-inducible cytochrome P450; catalyzes hy...      Plate 21
# orf19.100   Alpha/beta hydrolase and lipase domain protein...  GELCPlate 08
# orf19.1002  Protein of unknown function; Hap43-repressed gene  GELCPlate 08
# orf19.1005  Protein with predicted RNI-like domains; rat c...  GELCPlate 05
# orf19.101   Protein required for alkaline pH response via ...  GELCPlate 08
# ...                                                       ...           ...
# ...

# %%
df_1.index.unique()
# Out:
# Index(['orf19.10', 'orf19.100', 'orf19.1002', 'orf19.1005', 'orf19.101',
#        'orf19.1010', 'orf19.1011', 'orf19.1012', 'orf19.102', 'orf19.1028',
#        ...
#        'orf19.97', 'orf19.972', 'orf19.974', 'orf19.976', 'orf19.978',
#        'orf19.979', 'orf19.984', 'orf19.988', 'orf19.99', 'orf19.991'],
#       dtype='object', name='orf19', length=2263)

# %%
df_1.index[df_1.index.duplicated()]
# Out:
# Index(['orf19.1078', 'orf19.2665', 'orf19.2942', 'orf19.5655', 'orf19.5894'], dtype='object', name='orf19')

# %%
df_1.loc[df_1.index[df_1.index.duplicated()]]
# Out:
#                 feature   common  \
# orf19
# orf19.1078  C6_04220C_A     HBR2
# orf19.1078  C6_04220C_A     HBR2
# orf19.2665  C4_03280W_A     MSN5
# orf19.2665  C4_03280W_A     MSN5
# orf19.2942  C1_02530C_A     DIP5
# orf19.2942  C1_02530C_A     DIP5
# orf19.5655  C4_00290C_A      NaN
# orf19.5655  C4_00290C_A      NaN
# orf19.5894  C3_04440C_A  YEL023C
# orf19.5894  C3_04440C_A  YEL023C
#
#                                                   description     plate  \
# orf19
# orf19.1078  Putative alanine glyoxylate aminotransferase; ...  Plate 20
# orf19.1078  Putative alanine glyoxylate aminotransferase; ...  Plate 25
# orf19.2665  Predicted karyopherin involved in nuclear impo...  Plate 08
# orf19.2665  Predicted karyopherin involved in nuclear impo...  Plate 12
# orf19.2942  Dicarboxylic amino acid permease; mutation con...  Plate 14
# orf19.2942  Dicarboxylic amino acid permease; mutation con...  Plate 20
# ...

# %%
df_2.index.unique()
# Out:
# Index(['orf19.10', 'orf19.100', 'orf19.1002', 'orf19.1005', 'orf19.101',
#        'orf19.1010', 'orf19.1011', 'orf19.1012', 'orf19.102', 'orf19.1028',
#        ...
#        'orf19.97', 'orf19.972', 'orf19.974', 'orf19.976', 'orf19.978',
#        'orf19.979', 'orf19.984', 'orf19.988', 'orf19.99', 'orf19.991'],
#       dtype='object', name='orf19', length=2269)

# %%
np.intersect1d(df_1.index, df_2.index).shape
# Out:
# (2263,)

# %%
set(df_1.index) - set(np.intersect1d(df_1.index, df_2.index))
# Out:
# set()

# %%
set(df_2.index) - set(np.intersect1d(df_1.index, df_2.index))
# Out:
# {'orf19.407',
#  'orf19.4497',
#  'orf19.4771',
#  'orf19.50',
#  'orf19.7296',
#  'orf19.7306'}

# %%
df_2.loc[list(set(df_2.index) - set(np.intersect1d(df_1.index, df_2.index)))]
# Out:
#                 feature   common  \
# orf19
# orf19.7296  CR_08990C_A      NaN
# orf19.50    C1_04960C_A     UFO1
# orf19.407   C1_08600C_A     GCD6
# orf19.7306  CR_09100C_A  YPR127W
# orf19.4497  C2_04530W_A     MED8
# orf19.4771  C1_09130W_A      NaN
#
#                                                   description         plate  \
# orf19
# orf19.7296  Plasma membrane protein implicated in stress r...      Plate 23
# orf19.50    Ortholog(s) have role in SCF-dependent proteas...  GELCPlate 04
# orf19.407   Ortholog of S. cerevisiae Gcd6; catalytic epsi...      Plate 11
# orf19.7306  Aldo-keto reductase; increased transcript asso...      Plate 25
# orf19.4497  Ortholog(s) have RNA polymerase II proximal pr...      Plate 16
# orf19.4771  Protein of unknown function; Spider biofilm in...      Plate 19
#
#            position  A_Temp2_UP  A_Temp2_DN  B_Temp2_UP  B_Temp2_DN  \
# orf19
# orf19.7296      A12           0           0           0           0
# ...

# %%
# Decision: match the processed real data, drop duplicates and redundant to result in 2263 rows
df_ref = pd.read_csv('/Users/zhangxiang/Documents/Research_CB/GeneEssentiality_CandidaAlbicans/Emily_Xiong_analysis/EX_mod_t_pipeline_Dec2022/raw_read_data/sum_data_merged_renamed_fixed_02282023.tsv', sep='\t')

# %%
df_ref.set_index(['orf19', 'plate', 'position'], inplace=True)

# %%
df_1_filtered = df_1.reset_index().set_index(['orf19', 'plate', 'position']).loc[df_ref.index]

# %%
df_2_filtered = df_2.reset_index().set_index(['orf19', 'plate', 'position']).loc[df_ref.index]

# %%
df_1_filtered
# Out:
#                                       feature common  \
# orf19      plate        position
# orf19.6109 GELCPlate 01 G07       C1_00060W_A   TUP1
# orf19.6096 Plate 19     G09       C1_00120C_A   TRP1
# orf19.6094 Plate 04     B01       C1_00130C_A  VPS53
# orf19.6091 Plate 13     H05       C1_00150C_A   RIM8
# orf19.6090 GELCPlate 01 G08       C1_00160C_A   NSR1
# ...                                       ...    ...
# orf19.7666 Plate 24     F05       CR_10770W_A    NaN
# orf19.7668 Plate 23     D09       CR_10790W_A   IMA1
# orf19.7672 GELCPlate 06 G06       CR_10810C_A   DFM1
# orf19.7676 GELCPlate 08 D01       CR_10840C_A   SOR2
# orf19.7678 Plate 04     E01       CR_10850C_A  ATP16
#
#                                                                         description  \
# orf19      plate        position
# orf19.6109 GELCPlate 01 G07       Transcriptional corepressor; represses filamen...
# orf19.6096 Plate 19     G09       Phosphoribosylanthranilate isomerase; tryptoph...
# ...

# %%
df_2_filtered
# Out:
#                                       feature common  \
# orf19      plate        position
# orf19.6109 GELCPlate 01 G07       C1_00060W_A   TUP1
# orf19.6096 Plate 19     G09       C1_00120C_A   TRP1
# orf19.6094 Plate 04     B01       C1_00130C_A  VPS53
# orf19.6091 Plate 13     H05       C1_00150C_A   RIM8
# orf19.6090 GELCPlate 01 G08       C1_00160C_A   NSR1
# ...                                       ...    ...
# orf19.7666 Plate 24     F05       CR_10770W_A    NaN
# orf19.7668 Plate 23     D09       CR_10790W_A   IMA1
# orf19.7672 GELCPlate 06 G06       CR_10810C_A   DFM1
# orf19.7676 GELCPlate 08 D01       CR_10840C_A   SOR2
# orf19.7678 Plate 04     E01       CR_10850C_A  ATP16
#
#                                                                         description  \
# orf19      plate        position
# orf19.6109 GELCPlate 01 G07       Transcriptional corepressor; represses filamen...
# orf19.6096 Plate 19     G09       Phosphoribosylanthranilate isomerase; tryptoph...
# ...

# %%
df_merge = df_1_filtered.merge(df_2_filtered.drop(['feature', 'common', 'description'], axis=1), how='left', left_index=True, right_index=True)

# %%
df_merge = df_merge.reset_index().set_index('orf19')

# %%
df_merge
# Out:
#                    plate position      feature common  \
# orf19
# orf19.6109  GELCPlate 01      G07  C1_00060W_A   TUP1
# orf19.6096      Plate 19      G09  C1_00120C_A   TRP1
# orf19.6094      Plate 04      B01  C1_00130C_A  VPS53
# orf19.6091      Plate 13      H05  C1_00150C_A   RIM8
# orf19.6090  GELCPlate 01      G08  C1_00160C_A   NSR1
# ...                  ...      ...          ...    ...
# orf19.7666      Plate 24      F05  CR_10770W_A    NaN
# orf19.7668      Plate 23      D09  CR_10790W_A   IMA1
# orf19.7672  GELCPlate 06      G06  CR_10810C_A   DFM1
# orf19.7676  GELCPlate 08      D01  CR_10840C_A   SOR2
# orf19.7678      Plate 04      E01  CR_10850C_A  ATP16
#
#                                                   description  A_Temp1_UP  \
# orf19
# orf19.6109  Transcriptional corepressor; represses filamen...         905
# orf19.6096  Phosphoribosylanthranilate isomerase; tryptoph...          34
# orf19.6094  Ortholog(s) have role in Golgi to vacuole tran...         146
# ...

# %%
df_merge.columns
# Out:
# Index(['plate', 'position', 'feature', 'common', 'description', 'A_Temp1_UP',
#        'A_Temp1_DN', 'B_Temp1_UP', 'B_Temp1_DN', 'C_Temp1_UP', 'C_Temp1_DN',
#        'A_Temp1_DOX_UP', 'A_Temp1_DOX_DN', 'B_Temp1_DOX_UP', 'B_Temp1_DOX_DN',
#        'C_Temp1_DOX_UP', 'C_Temp1_DOX_DN', 'A_YNB1_UP', 'A_YNB1_DN',
#        'B_YNB1_UP', 'B_YNB1_DN', 'C_YNB1_UP', 'C_YNB1_DN', 'A_YNB1_DOX_UP',
#        'A_YNB1_DOX_DN', 'B_YNB1_DOX_UP', 'B_YNB1_DOX_DN', 'C_YNB1_DOX_UP',
#        'C_YNB1_DOX_DN', 'A_YNB2_UP', 'A_YNB2_DN', 'B_YNB2_UP', 'B_YNB2_DN',
#        'C_YNB2_UP', 'C_YNB2_DN', 'A_YNB2_DOX_UP', 'A_YNB2_DOX_DN',
#        'B_YNB2_DOX_UP', 'B_YNB2_DOX_DN', 'C_YNB2_DOX_UP', 'C_YNB2_DOX_DN',
#        'A_YNB3_UP', 'A_YNB3_DN', 'B_YNB3_UP', 'B_YNB3_DN', 'C_YNB3_UP',
#        'C_YNB3_DN', 'A_YNB3_DOX_UP', 'A_YNB3_DOX_DN', 'B_YNB3_DOX_UP',
#        'B_YNB3_DOX_DN', 'C_YNB3_DOX_UP', 'C_YNB3_DOX_DN', 'A_Temp2_UP',
#        'A_Temp2_DN', 'B_Temp2_UP', 'B_Temp2_DN', 'C_Temp2_UP', 'C_Temp2_DN',
# ...

# %%
df_merge = df_merge[['feature', 'common', 'description', 'plate', 'position', 
          'A_Temp1_UP', 'A_Temp1_DN', 'B_Temp1_UP', 'B_Temp1_DN', 'C_Temp1_UP', 'C_Temp1_DN',
          'A_Temp1_DOX_UP', 'A_Temp1_DOX_DN', 'B_Temp1_DOX_UP', 'B_Temp1_DOX_DN', 'C_Temp1_DOX_UP', 'C_Temp1_DOX_DN',
          'A_Temp2_UP', 'A_Temp2_DN', 'B_Temp2_UP', 'B_Temp2_DN', 'C_Temp2_UP', 'C_Temp2_DN',
          'A_Temp2_DOX_UP', 'A_Temp2_DOX_DN', 'B_Temp2_DOX_UP', 'B_Temp2_DOX_DN', 'C_Temp2_DOX_UP', 'C_Temp2_DOX_DN',
          'A_YNB1_UP', 'A_YNB1_DN', 'B_YNB1_UP', 'B_YNB1_DN', 'C_YNB1_UP', 'C_YNB1_DN', 
          'A_YNB1_DOX_UP', 'A_YNB1_DOX_DN', 'B_YNB1_DOX_UP', 'B_YNB1_DOX_DN', 'C_YNB1_DOX_UP', 'C_YNB1_DOX_DN', 
          'A_YNB2_UP', 'A_YNB2_DN', 'B_YNB2_UP', 'B_YNB2_DN', 'C_YNB2_UP', 'C_YNB2_DN', 
          'A_YNB2_DOX_UP', 'A_YNB2_DOX_DN', 'B_YNB2_DOX_UP', 'B_YNB2_DOX_DN', 'C_YNB2_DOX_UP', 'C_YNB2_DOX_DN',
          'A_YNB3_UP', 'A_YNB3_DN', 'B_YNB3_UP', 'B_YNB3_DN', 'C_YNB3_UP', 'C_YNB3_DN', 
          'A_YNB3_DOX_UP', 'A_YNB3_DOX_DN', 'B_YNB3_DOX_UP', 'B_YNB3_DOX_DN', 'C_YNB3_DOX_UP', 'C_YNB3_DOX_DN', 
          'A_YNB4_UP', 'A_YNB4_DN', 'B_YNB4_UP', 'B_YNB4_DN', 'C_YNB4_UP', 'C_YNB4_DN', 
          'A_YNB4_DOX_UP', 'A_YNB4_DOX_DN', 'B_YNB4_DOX_UP', 'B_YNB4_DOX_DN', 'C_YNB4_DOX_UP', 'C_YNB4_DOX_DN',
          'A_YNB5_UP', 'A_YNB5_DN', 'B_YNB5_UP', 'B_YNB5_DN', 'C_YNB5_UP', 'C_YNB5_DN', 
          'A_YNB5_DOX_UP', 'A_YNB5_DOX_DN', 'B_YNB5_DOX_UP', 'B_YNB5_DOX_DN', 'C_YNB5_DOX_UP', 'C_YNB5_DOX_DN']]

# %%
df_merge
# Out:
#                 feature common  \
# orf19
# orf19.6109  C1_00060W_A   TUP1
# orf19.6096  C1_00120C_A   TRP1
# orf19.6094  C1_00130C_A  VPS53
# orf19.6091  C1_00150C_A   RIM8
# orf19.6090  C1_00160C_A   NSR1
# ...                 ...    ...
# orf19.7666  CR_10770W_A    NaN
# orf19.7668  CR_10790W_A   IMA1
# orf19.7672  CR_10810C_A   DFM1
# orf19.7676  CR_10840C_A   SOR2
# orf19.7678  CR_10850C_A  ATP16
#
#                                                   description         plate  \
# orf19
# orf19.6109  Transcriptional corepressor; represses filamen...  GELCPlate 01
# orf19.6096  Phosphoribosylanthranilate isomerase; tryptoph...      Plate 19
# orf19.6094  Ortholog(s) have role in Golgi to vacuole tran...      Plate 04
# orf19.6091  Beta-arrestin-like protein; involved in pH res...      Plate 13
# orf19.6090  Putative nucleolar protein with a predicted ro...  GELCPlate 01
# ...                                                       ...           ...
# ...

# %%
df_merge.to_csv('protocol_data.tsv', sep='\t')

# %%
#09232024: identified column name order issues, just read in and reset the orders
# Affected data: B_YNB2_UP/DN,      A/B/C_Temp1_UP/DN 
df_merge = pd.read_csv('./input/protocol_data.tsv', sep='\t', index_col=0)

# %%
df_merge
# Out:
#                 feature common  \
# orf19
# orf19.6109  C1_00060W_A   TUP1
# orf19.6096  C1_00120C_A   TRP1
# orf19.6094  C1_00130C_A  VPS53
# orf19.6091  C1_00150C_A   RIM8
# orf19.6090  C1_00160C_A   NSR1
# ...                 ...    ...
# orf19.7666  CR_10770W_A    NaN
# orf19.7668  CR_10790W_A   IMA1
# orf19.7672  CR_10810C_A   DFM1
# orf19.7676  CR_10840C_A   SOR2
# orf19.7678  CR_10850C_A  ATP16
#
#                                                   description         plate  \
# orf19
# orf19.6109  Transcriptional corepressor; represses filamen...  GELCPlate 01
# orf19.6096  Phosphoribosylanthranilate isomerase; tryptoph...      Plate 19
# orf19.6094  Ortholog(s) have role in Golgi to vacuole tran...      Plate 04
# orf19.6091  Beta-arrestin-like protein; involved in pH res...      Plate 13
# orf19.6090  Putative nucleolar protein with a predicted ro...  GELCPlate 01
# ...                                                       ...           ...
# ...

# %%
df_merge = df_merge[['feature', 'common', 'description', 'plate', 'position', 
          'A_Temp1_UP', 'A_Temp1_DN', 'B_Temp1_UP', 'B_Temp1_DN', 'C_Temp1_UP', 'C_Temp1_DN',
          'A_Temp1_DOX_UP', 'A_Temp1_DOX_DN', 'B_Temp1_DOX_UP', 'B_Temp1_DOX_DN', 'C_Temp1_DOX_UP', 'C_Temp1_DOX_DN',
          'A_Temp2_UP', 'A_Temp2_DN', 'B_Temp2_UP', 'B_Temp2_DN', 'C_Temp2_UP', 'C_Temp2_DN',
          'A_Temp2_DOX_UP', 'A_Temp2_DOX_DN', 'B_Temp2_DOX_UP', 'B_Temp2_DOX_DN', 'C_Temp2_DOX_UP', 'C_Temp2_DOX_DN',
          'A_YNB1_UP', 'A_YNB1_DN', 'B_YNB1_UP', 'B_YNB1_DN', 'C_YNB1_UP', 'C_YNB1_DN', 
          'A_YNB1_DOX_UP', 'A_YNB1_DOX_DN', 'B_YNB1_DOX_UP', 'B_YNB1_DOX_DN', 'C_YNB1_DOX_UP', 'C_YNB1_DOX_DN', 
          'A_YNB2_UP', 'A_YNB2_DN', 'B_YNB2_UP', 'B_YNB2_DN', 'C_YNB2_UP', 'C_YNB2_DN', 
          'A_YNB2_DOX_UP', 'A_YNB2_DOX_DN', 'B_YNB2_DOX_UP', 'B_YNB2_DOX_DN', 'C_YNB2_DOX_UP', 'C_YNB2_DOX_DN',
          'A_YNB3_UP', 'A_YNB3_DN', 'B_YNB3_UP', 'B_YNB3_DN', 'C_YNB3_UP', 'C_YNB3_DN', 
          'A_YNB3_DOX_UP', 'A_YNB3_DOX_DN', 'B_YNB3_DOX_UP', 'B_YNB3_DOX_DN', 'C_YNB3_DOX_UP', 'C_YNB3_DOX_DN', 
          'A_YNB4_UP', 'A_YNB4_DN', 'B_YNB4_UP', 'B_YNB4_DN', 'C_YNB4_UP', 'C_YNB4_DN', 
          'A_YNB4_DOX_UP', 'A_YNB4_DOX_DN', 'B_YNB4_DOX_UP', 'B_YNB4_DOX_DN', 'C_YNB4_DOX_UP', 'C_YNB4_DOX_DN',
          'A_YNB5_UP', 'A_YNB5_DN', 'B_YNB5_UP', 'B_YNB5_DN', 'C_YNB5_UP', 'C_YNB5_DN', 
          'A_YNB5_DOX_UP', 'A_YNB5_DOX_DN', 'B_YNB5_DOX_UP', 'B_YNB5_DOX_DN', 'C_YNB5_DOX_UP', 'C_YNB5_DOX_DN']]

# %%
df_merge.to_csv('./input/protocol_example_data.tsv', sep='\t')
